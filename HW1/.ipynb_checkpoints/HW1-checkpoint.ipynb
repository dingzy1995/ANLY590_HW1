# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoCV
from sklearn import linear_model

# %%
df = pd.read_csv("Hitters.csv")
df.head()
# Out:
#           Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     -Andy Allanson    293    66      1    30   29     14      1     293
# 1        -Alan Ashby    315    81      7    24   38     39     14    3449
# 2       -Alvin Davis    479   130     18    66   72     76      3    1624
# 3      -Andre Dawson    496   141     20    65   78     37     11    5628
# 4  -Andres Galarraga    321    87     10    39   42     30      2     396
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# 0     66  ...     30    29      14       A        E     446       33      20
# 1    835  ...    321   414     375       N        W     632       43      10
# 2    457  ...    224   266     263       A        W     880       82      14
# 3   1575  ...    828   838     354       N        E     200       11       3
# 4    101  ...     48    46      33       N        E     805       40       4
#
#    Salary  NewLeague
# 0     NaN          A
# ...

# %%
# name = df['Unnamed: 0']
xs = df.drop(['Unnamed: 0', 'League', 'Division', 'NewLeague', 'Salary'], axis = 1)
xs_test = xs.tail(50)
xs = xs[:272]
xs.fillna(method = 'pad')
y = df['Salary']
y_test = y.tail(50)
y_test = y_test.fillna(method = 'bfill')
y = y[:272]
y = y.fillna(method = 'bfill')
y.values.reshape(-1, 1)

lasso = Lasso(alpha=12)
y_lasso = lasso.fit(xs, y).predict(xs_test)

print(str(lasso.coef_))
plt.plot(lasso.coef_, label='Lasso coefficients')
plt.legend(loc='best')
plt.show()
# Out:
# [-2.28913826  7.27888141  4.37855528 -1.36922468 -0.25337797  5.00544678
#  -0.16474065 -0.13175718 -0.61890868 -2.0317908   2.41448276  1.39274804
#  -0.93783824  0.31952738  0.49507906 -3.43353045]
# C:\conda\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15658398.340556009, tolerance: 5508.956607582999
#   positive)

# %% [markdown]
# The 3 final three predictors that remain in the model are Hits, HmRun and Walks

# %%
lassocv = LassoCV()
lassocv.fit(xs, y)
alpha = lassocv.alpha_
print(alpha)

lasso = Lasso(alpha=alpha)
y_lasso = lasso.fit(xs, y).predict(xs_test)
#number of nonzero coefficients
n = np.sum(lasso.coef_ != 0)
print(str(n))
plt.plot(lasso.coef_, label='LassoCV coefficients')
plt.legend(loc='best')
plt.show()
# Out:
# C:\conda\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 445.14719961443046
# 9

# %% [markdown]
# By cross validation, the optimal value of the regularization penality is 445.147,9 predictors are left in
# the model

# %%
ridg = linear_model.Ridge (alpha = 15)
y_ridg = ridg.fit(xs, y).predict(xs_test)

print(str(ridg.coef_))

plt.plot(ridg.coef_, label='ridge coefficients')
plt.legend(loc='best')
plt.show()
# Out:
# [-2.41169903  8.24601342  7.12316853 -2.57254327 -1.12097693  5.41032293
#  -5.48972962 -0.0782465  -0.9037807  -2.62985415  2.6193378   1.63153435
#  -1.00936898  0.31829282  0.50722323 -4.04304742]

# %% [markdown]
# The final 3 predictors of this model are Hits, HmRun and Years.

# %%
ridgecv = linear_model.RidgeCV()
ridgecv.fit(xs, y)
alpha = ridgecv.alpha_
print(alpha)

ridg = linear_model.Ridge (alpha = alpha)
y_ridg = ridg.fit(xs, y).predict(xs_test)
n = np.sum(lasso.coef_ != 0)
print(str(n))
plt.plot(ridg.coef_, label='ridge coefficients')
plt.legend(loc='best')
plt.show()
# Out:
# 10.0
# 16

# %% [markdown]
# By cross validation, the optimal value of the regularization penality is 10.0, 16 predictors are left in
# the model
